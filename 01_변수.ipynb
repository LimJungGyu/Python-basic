# %% [markdown]
# # 01.변수와 자료형
# ---
# * 날짜:
# * 이름:

# %% [markdown]
# ## 개념정리
# ---

# %% [markdown]
# ### **(1) 변수**
#
# 변수란 값이 들어가는 상자라고 생각하면 됩니다. 변수를 지정하는 것을 바인딩이라고 합니다. 바인딩(binding)이란 프로그램에 사용된 구성 요소의 실제 값 또는 프로퍼티를 결정짓는 행위를 의미합니다.

# %% [markdown]
# **1. 수치자료형의 선언**
#
# 숫자 2를 a 로 바인딩을 하였습니다. 이 때 바인딩된 a의 타입은 수치 자료형 중 정수형 자료형(int)입니다.
#
# ```
# a=2
# ```

# %%
a=2

# %% [markdown]
# **2. 문자열 자료형의 선언**
#
# 아래는 문자열 "apple"을 b 로 바인딩 하였습니다. 이 때 바인딩된 b의 타입은 문자열자료형(str)입니다.
#
# ```
# b="apple"
# ```

# %%
b="apple"

# %% [markdown]
# **3. 재바인딩**
#
# 바인딩된 값을 다시 바인딩하면 기존 데이터는 사라집니다.
# ```
# a = a+3
# a
# ```

# %%
a=a+3
a
# Out:
# 11

# %% [markdown]
# **4. 바인딩에러**
#
# 바인딩 한적이 없는 값을 출력하면 에러가 뜹니다.
#
# ```
# >> print(C)
# ```

# %%
print("안녕하세요")
# Out:
# 1

# %% [markdown]
# ### **(2) 자료형 확인**
#
#
# 데이터의 자료형을 확인하는 것은 프로그래밍에 있어서 아주 중요합니다. 내가 변수로 지정한 값들이 어떤 자료형인지 잘 알고 있어야 각 자료형에 맞는 코드를 작성할 수 있습니다. 파이썬의 자료형에는 **리스트, 문자열 튜플, 딕셔너리, 집합, 수치, 불** 등이 있습니다. 간단하게 수치자료형과 문자열자료형으로 데이터 자료형을 확인해보고 나머지 자료형에 대해서는 추후 더 자세히 알아보도록 합니다.

# %% [markdown]
# **1. type()**
#
# 데이터의 자료형을 아래와 같이 확인 할 수 있습니다. 아래는 정수자료형 예시입니다. 정수자료형의 type 결과를 확인해봅니다.
#
# ```
# type(2)
# ```
# ```
# num = 2
# type(num)
# ```

# %%
type(2)
# Out:
# int

# %%
num =2
type(num)
# Out:
# int

# %% [markdown]
# 아래는 문자열 자료형 예시입니다. 문자열 자료형의 type 결과를 확인해봅니다.
#
# ```
# type('a')
# ```
# ```
# alphabet = 'a'
# type(alphabet)
# ```

# %% [markdown]
# **2. 타입변환**
#
# 숫자로 이루어졌어도 따음표를 사용해 작성하면 문자열 자료형으로 저장됩니다. 하지만 숫자로 이루어진 값들은 int() 혹은 str()를 이용해 타입을 변환할 수 있습니다.
#
# ```
# c = "123"
# c, type(c)
# ```
#
# ```
# c = int(c)
# c, type(c)
# ```

# %%
c="123"
c,type(c)
# Out:
# ('123', str)

# %%
c = int(c)
c,type(c)
# Out:
# (123, int)

# %% [markdown]
# ## 예제
# ---

# %% [markdown]
# #####**예제 01**
#
# 아래 변수에 바인딩된 값의 타입을 판별해보세요.
#
#
# ```
# a = 132
# ```

# %%
a=132
type(a)
# Out:
# int

# %% [markdown]
# #####**예제 02**
#
# 아래 변수에 바인딩된 값의 타입을 판별해보세요.
#
#
# ```
# a = "132"
# ```

# %%
a="132"
type(a)
# Out:
# str

# %% [markdown]
# #####**예제 03**
#
# 위에서 바인딩된 a를 int로 타입을 변경하세요

# %%
a=int(a)
type(a)
# Out:
# int

# %% [markdown]
# #####**예제 04**
#
# 위에서 바인딩된 a를 str로 타입을 변경하세요

# %%
a=str(a)
type(a)
# Out:
# str

# %% [markdown]
# #####**예제 05**
#
# 아래 값의 최종 결과를 예측하세요
#
#
# ```
# a = 1
# a = a+1
# a = a+2
# a
# ```

# %%
a=1
a=a+1
a=a+2
a
# Out:
# 4

# %% [markdown]
# #####**예제 06**
#
# 아래 값의 최종 결과를 예측하세요
#
#
# ```
# a = '12345'
# a = '54321'
# a = int(a)
# a = a+1000
# a
# ```

# %%
a = '12345'
a = '54321'
a= int(a)
a= a+1000
a
# Out:
# 55321

# %% [markdown]
# #####**예제 07**
#
# 아래 코드를 실행해보고 에러가 뜨는 이유를 설명하세요
#
# ```
# a = '12345'
# a = a+1000
# a
# ```

# %%
a='12345'
a= a+1000
a
print "str int 타입불일치"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b617dbafbf11> in <module>()
#       1 a='12345'
# ----> 2 a= a+1000
#       3 a
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# #####**예제 08**
#
# 아래 코드를 실행해보고 에러가 뜨는 이유를 설명하세요
#
# ```
# a = 1
# b = 2
# a+b+c
# ```

# %%
a=1
b=2
a+b+c
# Out:
# 126

# %%
변수 C 선언이 없음
