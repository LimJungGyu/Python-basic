# %%
sd

# %%
djflk

# %% [markdown]
# # 코딩테스트 도전하기 2
#
# 코드문제 제공 사이트
#
# * 프로그래머스 https://programmers.co.kr/
# * 백준 https://www.acmicpc.net/workbook/top

# %% [markdown]
# ## 프로그래머스 1단계 문제 도전하기
#
# 1. 완주하지 못한 선수: https://programmers.co.kr/learn/courses/30/lessons/42576?language=python3
# 2. k번째 수 : https://programmers.co.kr/learn/courses/30/lessons/42748?language=python3
# 3. 모의고사: https://programmers.co.kr/learn/courses/30/lessons/42840?language=python3
# 4. 체육복: https://programmers.co.kr/learn/courses/30/lessons/42862?language=python3

# %% [markdown]
# ### 1. 완주하지 못한 선수
# ---
#
# 주소: https://programmers.co.kr/learn/courses/30/lessons/42576?language=python3

# %% [markdown]
# **나의 풀이**

# %%
def solution(participant, completion):
  completion.sort()
  participant.sort()
  if len(set(completion))==len(set(participant)):
    for i in range(len(completion)):
      if completion[i] !=participant[i] and completion[i] ==participant[i+1]:
        return participant[i]
  else: 
    return list(set(participant)-set(completion))[0]
      
solution(["mislav", "stanko", "mislav", "ana"],["stanko", "ana", "mislav"])
# Out:
# 'mislav'

# %% [markdown]
# **다른사람의 풀이**

# %%
import collections


def solution(participant, completion):
    answer = collections.Counter(participant) - collections.Counter(completion)
    return list(answer.keys())[0]

# %% [markdown]
# ### 2. k번째 수
# ---
#
# https://programmers.co.kr/learn/courses/30/lessons/42748?language=python3

# %% [markdown]
# **나의 풀이**

# %%
def solution(array, commands):
  answer=[]
  for i in range(len(commands)):
    answer.append(sorted(array[commands[i][0]-1:commands[i][1]])[commands[i][2]-1])
  return answer

solution([1, 5, 2, 6, 3, 7, 4],[[2, 5, 3], [4, 4, 1], [1, 7, 3]]	)
# Out:
# [5, 6, 3]

# %% [markdown]
# **다른사람의 풀이**

# %%
def solution(array, commands):
    return list(map(lambda x:sorted(array[x[0]-1:x[1]])[x[2]-1], commands))

# %% [markdown]
# ### 3. 모의고사
# ---
#
# https://programmers.co.kr/learn/courses/30/lessons/42840?language=python3

# %% [markdown]
# **나의 풀이**

# %%
def solution(answers):
    answer = []
    수포자1 = [1, 2, 3, 4, 5]
    수포자2 = [2, 1, 2, 3, 2, 4, 2, 5]
    수포자3 = [3, 3, 1, 1, 2, 2, 4, 4, 5, 5]
    점수= [0,0,0]
    for i in range(len(answers)):
      if   answers[i]==(수포자1 * int(len(answers)/len(수포자1)+1))[i]:
        점수[0] +=1
    for i in range(len(answers)):
      if answers[i]==(수포자2 * int(len(answers)/len(수포자2)+1))[i]:
        점수[1] +=1
    for i in range(len(answers)):
      if answers[i]==(수포자3 * int(len(answers)/len(수포자3)+1))[i]:
        점수[2] +=1

    for i in range(3):
      if 점수[i]==max(점수):
        answer.append(i+1)
    return answer
    
      
solution([1,3,2,4,2])
# Out:
# [1, 2, 3]

# %% [markdown]
# **다른사람의 풀이**

# %%
def solution(answers):
    pattern1 = [1,2,3,4,5]
    pattern2 = [2,1,2,3,2,4,2,5]
    pattern3 = [3,3,1,1,2,2,4,4,5,5]
    score = [0, 0, 0]
    result = []

    for idx, answer in enumerate(answers):
        if answer == pattern1[idx%len(pattern1)]:
            score[0] += 1
        if answer == pattern2[idx%len(pattern2)]:
            score[1] += 1
        if answer == pattern3[idx%len(pattern3)]:
            score[2] += 1

    for idx, s in enumerate(score):
        if s == max(score):
            result.append(idx+1)

    return result

# %% [markdown]
# ### 4. 체육복
# ---
# https://programmers.co.kr/learn/courses/30/lessons/42862?language=python3

# %% [markdown]
# **나의 풀이**

# %%
def solution(n, lost, reserve):
  answer = n - len(lost)
  
  for i in range(len(reserve)):

    if reserve[i]+1 in lost:
      lost[lost.index(reserve[i]+1)]=32
      answer += 1
      continue
    elif  reserve[i]-1 in lost:
      lost[lost.index(reserve[i]-1)]=32
      answer += 1
      continue
  return answer

solution(5,[2, 4],[1, 3, 5]	)
# Out:
# 5

# %% [markdown]
# **다른사람의 풀이**
